# %%
from cleaning_data import *
import re
import pandas as pd

dirty_data = load_csv("dirty_dataset.csv")
dirty_data
# Out:
#                                     user_id                             name  \
# 0      788f3808-bc11-4555-81c0-82de2928ebe9                  Ivo Riccardixxx
# 1                                      2824               Fulvio Sismondin/a
# 2                                       NaN                  Elisa Simeoni??
# 3      c8db0ce6-2f8f-4699-8e2a-c3af367f0742              Daria Vanvitellin/a
# 4      cddf2e27-d51f-4e6c-85aa-ba3c634a10ca              Beatrice Tencalla
# ...                                     ...                              ...
# 50995                                  8249                  Renzo Draghixxx
# 50996  1f4ecb21-3467-4539-b88e-b046b891b15f               Mercedes Boezioxxx
# 50997  88834303-7350-4c9b-8600-06fbbf79f9af                  Rossana Ciampi
# 50998                                   NaN             Ruggiero Marangoni
# 50999                                  3426  Guglielmo Micheletti-Fattori###
#
#                                email      age signup_date     last_login  \
# 0       pietrobertolucci@example.org  unknown    24-11-23  not_available
# 1                          fiannuzzi      NaN  09-03-2025  not_available
# 2       silvestrirolando@example.com       -5  10/03/2022     05-27-2025
# 3                 rosa95@example.net      NaN    04-03-24            NaN
# 4                   dossettipasquale      NaN  2023-08-19            NaN
# ...                              ...      ...         ...            ...
# 50995             pier97@example.com       58    13-09-22            NaN
# 50996            igolino@example.com       -5  2023-02-19            NaN
# 50997            livia65@example.org       -5    18-10-24            NaN
# 50998    roccoborsellino@example.com  unknown  23/08/2025  not_available
# 50999  ferdinandonaccari@example.org       78  01/01/2023     10-02-2022
#
#       country                    city purchase_amount category discount_code  \
# 0         NaN              Pandola###          249.72       ??           NaN
# 1          IT              Acquaron/a          498.08       ??          IV59
# 2      Italia           Campestrinxxx          169.87  Fashion           NaN
# 3         NaN             Governolo             77.61       ??           NaN
# 4      Italia  San Vincenzo A Torri            455,25     Tech          FT44
# ...       ...                     ...             ...      ...           ...
# 50995   italy          Muriscuvo'NULL          224.03     HOME           NaN
# 50996   Italy               Ridotti            338.18       ??           NaN
# 50997   italy             Grignanon/a          379.41     Tech           NaN
# 50998   italy              Schennan/a          365.38     Home           NaN
# 50999   Italy            Portosecco            469.38     HOME          TG57
#
#       rating reviews_count returned
# 0          1           NaN      NaN
# 1          2          many      yes
# 2          4          many       no
# 3       five           NaN     True
# 4        NaN           715       no
# ...      ...           ...      ...
# 50995      5           NaN    False
# 50996   five           NaN     True
# 50997    NaN           NaN       no
# 50998      5          many       no
# 50999   five          many     True
#
# [51000 rows x 14 columns]

# %%
regex = r'^(?![a-f0-9]{8}-[a-f0-9]{4}-[a-f0-9]{4}-[a-f0-9]{4}-[a-f0-9]{12}$)'
filtred_id = clean_pattern_column(dirty_data, "user_id", regex)
filtred_id.dropna(subset=["user_id"], inplace=True)
filtred_id
# Out:
#                                     user_id                     name  \
# 0      788f3808-bc11-4555-81c0-82de2928ebe9          Ivo Riccardixxx
# 3      c8db0ce6-2f8f-4699-8e2a-c3af367f0742      Daria Vanvitellin/a
# 4      cddf2e27-d51f-4e6c-85aa-ba3c634a10ca      Beatrice Tencalla
# 6      bedd5433-0834-44f7-ac07-97c08027a2be          Emma Dibiasixxx
# 7      d5c99441-b19a-4d5f-8261-79e93b7e009a            Anita Volta??
# ...                                     ...                      ...
# 50990  0d6f55aa-3b6d-4346-9709-9f04b1daf8ab  Aurora Curiel-Canova###
# 50991  03f60bd8-3c8e-4f79-9a9e-b186fe16a042   Priscilla Letta-Capone
# 50992  07380440-2046-4a09-b968-cf0a267885ae   Elmo Mogherini-Perini
# 50996  1f4ecb21-3467-4539-b88e-b046b891b15f       Mercedes Boezioxxx
# 50997  88834303-7350-4c9b-8600-06fbbf79f9af          Rossana Ciampi
#
#                               email      age signup_date     last_login  \
# 0      pietrobertolucci@example.org  unknown    24-11-23  not_available
# 3                rosa95@example.net      NaN    04-03-24            NaN
# 4                  dossettipasquale      NaN  2023-08-19            NaN
# 6       cleliabrambilla@example.com      NaN  11-11-2021     2023/10/29
# 7              avitturi@example.com       -5  2021-12-05       11-02-24
# ...                             ...      ...         ...            ...
# 50990   ferrarisronaldo@example.org       21  2024/11/16  not_available
# 50991     amaldiiolanda@example.com       65  2024/12/31     10-14-2021
# 50992        vemanuelli@example.com  unknown  2025/08/11       23-05-23
# 50996           igolino@example.com       -5  2023-02-19            NaN
# 50997           livia65@example.org       -5    18-10-24            NaN
#
#       country                    city purchase_amount  category discount_code  \
# 0         NaN              Pandola###          249.72        ??           NaN
# 3         NaN             Governolo             77.61        ??           NaN
# 4      Italia  San Vincenzo A Torri            455,25      Tech          FT44
# 6       Italy            Terrasinin/a           99.88  fashion            NaN
# 7          IT             Mezzolara            387.03       TEC          fB81
# ...       ...                     ...             ...       ...           ...
# 50990  Italia                  Umbra           215,96      Home           NaN
# 50991     NaN                   Tarzo          433.67       TEC           NaN
# 50992   Italy           Bricherasio??          356.81      Tech           NaN
# 50996   Italy               Ridotti            338.18        ??           NaN
# 50997   italy             Grignanon/a          379.41      Tech           NaN
#
#       rating reviews_count returned
# 0          1           NaN      NaN
# 3       five           NaN     True
# 4        NaN           715       no
# 6          3           NaN      yes
# 7          4            58      yes
# ...      ...           ...      ...
# 50990      3          many    False
# 50991      3          many      NaN
# 50992      5           NaN      yes
# 50996   five           NaN     True
# 50997    NaN           NaN       no
#
# [17102 rows x 14 columns]
